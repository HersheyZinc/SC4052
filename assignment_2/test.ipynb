# %%
import requests, os
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")
GITHUB_TOKEN
# Out:
# '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'

# %%
def search_github_repo():
    return


def openai_query(prompt, model="GPT-4o-mini"):
    return



def get_summary(prompt):
    return

# %%
num_results = 10
query = "SC4001"


headers = {'Authorization':f'Bearer {GITHUB_TOKEN}'}
url = f"https://api.github.com/search/repositories?q={query}+in:name+in:description+in:topics+in:readme"

# %%
response = requests.get(query, headers=headers).json()

# %%
response
# Out:
# {'total_count': 66,
#  'incomplete_results': False,
#  'items': [{'id': 281829858,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyODE4Mjk4NTg=',
#    'name': 'CombSleepNet',
#    'full_name': 'kme0155/CombSleepNet',
#    'private': False,
#    'owner': {'login': 'kme0155',
#     'id': 19407018,
#     'node_id': 'MDQ6VXNlcjE5NDA3MDE4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/19407018?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/kme0155',
#     'html_url': 'https://github.com/kme0155',
#     'followers_url': 'https://api.github.com/users/kme0155/followers',
#     'following_url': 'https://api.github.com/users/kme0155/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/kme0155/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/kme0155/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/kme0155/subscriptions',
# ...
